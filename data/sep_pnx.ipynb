# %%
import re
from string import punctuation
from camel_tools.utils.charsets import UNICODE_PUNCT_SYMBOL_CHARSET
from collections import defaultdict, Counter

PNX = punctuation + ''.join(list(UNICODE_PUNCT_SYMBOL_CHARSET)) + '&amp;'
pnx_patt = re.compile(r'(['+re.escape(PNX)+'])')

# %%
def read_data(path):
    with open(path) as f:
        return [x.strip() for x in f.readlines()]

# %%
def reconstruct_edit(pnx_edit, no_pnx_edit):
    def parse_edits(edit_string):
        """Parse edits into grouped operations."""
        return re.findall(r'I_\[.*?\]+|R_\[.*?\]+|A_\[.*?\]+|D|K|.', edit_string)

    def is_insert_or_append(edit):
        """Check if the edit is an insert or append operation."""
        return edit.startswith('I') or edit.startswith('A')

    def is_replace(edit):
        """Check if the edit is a replace operation."""
        return edit.startswith('R')

    # Parse the edits and initialize counters
    pnx_grouped_edits = parse_edits(pnx_edit)
    no_pnx_grouped_edits = parse_edits(no_pnx_edit)
    pnx_edit_cnts = Counter(pnx_grouped_edits)
    no_pnx_edit_cnts = Counter(edit for edit in no_pnx_grouped_edits if not is_insert_or_append(edit))

    
    i, j = 0, 0
    reconstructed_edit = ""

    # Merge edits
    while i < len(pnx_grouped_edits) and j < len(no_pnx_grouped_edits):
        pnx_edit = pnx_grouped_edits[i]
        no_pnx_edit = no_pnx_grouped_edits[j]

        # adding no pnx edit if pnx_edit is K and the no_pnx_edit is in [K, D, M, R]
        if pnx_edit == 'K' and (no_pnx_edit in ['K', 'D', 'M'] or is_replace(no_pnx_edit)):
            reconstructed_edit += no_pnx_edit
            pnx_edit_cnts[pnx_edit] -= 1
            no_pnx_edit_cnts[no_pnx_edit] -= 1
            i += 1
            j += 1

        # adding pnx edit if pnx edit is replace and no pnx edit is K
        elif is_replace(pnx_edit) and no_pnx_edit == 'K':
            reconstructed_edit += pnx_edit
            pnx_edit_cnts[pnx_edit] -= 1
            no_pnx_edit_cnts[no_pnx_edit] -= 1
            i += 1
            j += 1

        elif is_insert_or_append(pnx_edit):
            if pnx_edit_cnts['K'] != 0 and sum(no_pnx_edit_cnts.values()) == pnx_edit_cnts['K']:
                reconstructed_edit += pnx_edit
                i += 1
            else:
                reconstructed_edit += no_pnx_edit
                j += 1
        else:
            reconstructed_edit += no_pnx_edit
            j += 1


    # adding remaining edits
    reconstructed_edit += ''.join(no_pnx_grouped_edits[j:])
    reconstructed_edit += ''.join(pnx_grouped_edits[i:])
    
    return reconstructed_edit

# %%
def separate_pnx(edit):
    """
    Given an edit, returns two edits. One for pnx edits and one for no pnx edits.
    """
    grouped_edits = re.findall(r'I_\[.*?\]+|R_\[.*?\]+|A_\[.*?\]+|D+|K+|.', edit)

    pnx_edit = ''
    no_pnx_edit = '' 
    found_pnx = False

    for g_edit in grouped_edits:
        if g_edit.startswith('A_[') or g_edit.startswith('I_[') or g_edit.startswith('R_['):
            op = g_edit[0]
            seq = re.sub(op + r'_\[(.*?)\]', r'\1', g_edit)
            seq = re.sub(' +', '', seq)

            if pnx_patt.findall(seq) and ''.join(pnx_patt.findall(seq)) == seq:
                pnx_edit += g_edit
                found_pnx = True 
                if op == 'R':
                    no_pnx_edit += 'K'
            else:
                no_pnx_edit += g_edit
                if g_edit.startswith('R_['):
                    pnx_edit += 'K'

        elif g_edit:
            no_pnx_edit += g_edit
            if not (g_edit.startswith('I') and g_edit.startswith('M') and g_edit.startswith('A')):
                pnx_edit += 'K' * len(g_edit)
    
    if found_pnx == False:
        pnx_edit = ''


    re_edit = reconstruct_edit(pnx_edit=pnx_edit, no_pnx_edit=no_pnx_edit)
    if re_edit != edit:
        print(re_edit)
        print(edit)
        print({'no_pnx_edit': no_pnx_edit, 'pnx_edit': pnx_edit})
        print()
    return {'no_pnx_edit': no_pnx_edit, 'pnx_edit': pnx_edit}

# %%
edits = read_data('compress_me.txt')

# %%
separate_pnx('KI_[يين]A_[، "]')
# Out:
# > /var/folders/b8/39h0_97j63lcj_0g_cml6phm0000gn/T/ipykernel_63042/878684517.py(17)separate_pnx()
#      15             seq = re.sub(' +', '', seq)
#      16             import pdb; pdb.set_trace()
# ---> 17             if pnx_patt.match(seq) and pnx_patt.match(seq)[1] == seq:
#      18                 pnx_edit += g_edit
#      19                 found_pnx = True
#
# > /var/folders/b8/39h0_97j63lcj_0g_cml6phm0000gn/T/ipykernel_63042/878684517.py(17)separate_pnx()
#      15             seq = re.sub(' +', '', seq)
#      16             import pdb; pdb.set_trace()
# ---> 17             if pnx_patt.match(seq) and pnx_patt.match(seq)[1] == seq:
#      18                 pnx_edit += g_edit
#      19                 found_pnx = True
#
# '،"'
# <re.Match object; span=(0, 1), match='،'>

# %%
reconstruct_edit(pnx_edit='KA_[.]', no_pnx_edit='K')
# Out:
# 'KA_[.]'

# %%
for edit in edits:
    pnx_sep = separate_pnx(edit)
    # print(f'<s>{pnx_sep["no_pnx_edit"]}<s>\t<s>{pnx_sep["pnx_edit"]}<s>')
    if pnx_sep["pnx_edit"]:
        print(f'Edit:    {edit}')
        print(f'Pnx:     {pnx_sep["pnx_edit"]}')
        print(f'NoPnx:   {pnx_sep["no_pnx_edit"]}')
        print()
# Out:
# Edit:    I_[:]
# Pnx:     I_[:]
# NoPnx:
#
# Edit:    R_[!]
# Pnx:     R_[!]
# NoPnx:   K
#
# Edit:    I_[.]
# Pnx:     I_[.]
# NoPnx:
#
# Edit:    I_[،]
# Pnx:     I_[،]
# NoPnx:
#
# Edit:    I_[؟]
# Pnx:     I_[؟]
# NoPnx:
#
# Edit:    R_[:]
# Pnx:     R_[:]
# NoPnx:   K
#
# Edit:    R_[،]
# Pnx:     R_[،]
# NoPnx:   K
#
# Edit:    I_[؛]
# Pnx:     I_[؛]
# NoPnx:
#
# Edit:    I_["]
# Pnx:     I_["]
# NoPnx:
#
# Edit:    R_[؟]
# Pnx:     R_[؟]
# NoPnx:   K
#
# Edit:    R_[(]
# Pnx:     R_[(]
# NoPnx:   K
#
# Edit:    R_[)]
# Pnx:     R_[)]
# NoPnx:   K
#
# Edit:    R_[.]
# Pnx:     R_[.]
# NoPnx:   K
#
# Edit:    R_["]
# Pnx:     R_["]
# NoPnx:   K
#
# Edit:    I_[!]
# Pnx:     I_[!]
# NoPnx:
#
# Edit:    I_[-]
# Pnx:     I_[-]
# NoPnx:
#
# Edit:    R_[.]DDDD
# Pnx:     R_[.]KKKK
# NoPnx:   KDDDD
#
# Edit:    R_[ ]I_[،]
# Pnx:     KI_[،]
# NoPnx:   R_[ ]
#
# Edit:    R_[ا]I_[ ]R_[،]
# Pnx:     KR_[،]
# NoPnx:   R_[ا]I_[ ]K
#
# Edit:    R_[ ]I_[.]
# Pnx:     KI_[.]
# NoPnx:   R_[ ]
#
# Edit:    I_[(]
# Pnx:     I_[(]
# NoPnx:
#
# Edit:    I_[)]
# Pnx:     I_[)]
# NoPnx:
#
# Edit:    R_[!]I_[ ]KD
# Pnx:     R_[!]KK
# NoPnx:   KI_[ ]KD
#
# Edit:    I_[و]KKKR_[ ]I_[،]D
# Pnx:     KKKKI_[،]K
# NoPnx:   I_[و]KKKR_[ ]D
#
# Edit:    KKKKR_[ ]I_[،]D
# Pnx:     KKKKKI_[،]K
# NoPnx:   KKKKR_[ ]D
#
# Edit:    R_[-]
# Pnx:     R_[-]
# NoPnx:   K
#
# Edit:    KR_[ا]I_[ ]R_[.]
# Pnx:     KKR_[.]
# NoPnx:   KR_[ا]I_[ ]K
#
# Edit:    R_[،]I_[ ]KK
# Pnx:     R_[،]KK
# NoPnx:   KI_[ ]KK
#
# Edit:    I_[.]DDD
# Pnx:     I_[.]KKK
# NoPnx:   DDD
#
# Edit:    KR_[ ]I_[،]
# Pnx:     KKI_[،]
# NoPnx:   KR_[ ]
#
# Edit:    R_[،]DDDD
# Pnx:     R_[،]KKKK
# NoPnx:   KDDDD
#
# Edit:    I_[ن]KR_[ ]I_[.]
# Pnx:     KKI_[.]
# NoPnx:   I_[ن]KR_[ ]
#
# Edit:    I_[ ]R_[،]I_[ أ]K
# Pnx:     R_[،]K
# NoPnx:   I_[ ]KI_[ أ]K
#
# Edit:    R_[؟]D
# Pnx:     R_[؟]K
# NoPnx:   KD
#
# Edit:    I_[ ]R_[؟]
# Pnx:     R_[؟]
# NoPnx:   I_[ ]K
#
# Edit:    R_[ ]I_[.]DD
# Pnx:     KI_[.]KK
# NoPnx:   R_[ ]DD
#
# Edit:    R_[ ]I_[،]R_[ ]D
# Pnx:     KI_[،]KK
# NoPnx:   R_[ ]R_[ ]D
#
# Edit:    R_[ة]I_[ ]R_[،]
# Pnx:     KR_[،]
# NoPnx:   R_[ة]I_[ ]K
#
# Edit:    R_[؛]
# Pnx:     R_[؛]
# NoPnx:   K
#
# Edit:    KR_[ ]I_[.]
# Pnx:     KKI_[.]
# NoPnx:   KR_[ ]
#
# Edit:    R_[أ]I_[ت]R_[ ]R_[،]
# Pnx:     KKR_[،]
# NoPnx:   R_[أ]I_[ت]R_[ ]K
#
# Edit:    KKI_[ا]KR_[ ]I_[.]
# Pnx:     KKKKI_[.]
# NoPnx:   KKI_[ا]KR_[ ]
#
# Edit:    R_[؟]I_[ ]KK
# Pnx:     R_[؟]KK
# NoPnx:   KI_[ ]KK
#
# Edit:    R_[ ]I_[،]D
# Pnx:     KI_[،]K
# NoPnx:   R_[ ]D
#
# Edit:    I_[ ]R_[.]
# Pnx:     R_[.]
# NoPnx:   I_[ ]K
#
# Edit:    R_[.]I_[ ]KKK
# Pnx:     R_[.]KKK
# NoPnx:   KI_[ ]KKK
#
# Edit:    R_[/]
# Pnx:     R_[/]
# NoPnx:   K
#
# Edit:    I_[،]D
# Pnx:     I_[،]K
# NoPnx:   D
#
# Edit:    R_[ ]I_[!]
# Pnx:     KI_[!]
# NoPnx:   R_[ ]
#
# Edit:    R_[ ]I_[-]
# Pnx:     KI_[-]
# NoPnx:   R_[ ]
#
# Edit:    R_[ ]I_[.]DDDDDDD
# Pnx:     KI_[.]KKKKKKK
# NoPnx:   R_[ ]DDDDDDD
#
# Edit:    R_[،]DD
# Pnx:     R_[،]KK
# NoPnx:   KDD
#
# Edit:    KKKR_[ه]I_[ ]R_[،]
# Pnx:     KKKKR_[،]
# NoPnx:   KKKR_[ه]I_[ ]K
#
# Edit:    R_[؟]I_[ ]KR_[أ]K
# Pnx:     R_[؟]KKK
# NoPnx:   KI_[ ]KR_[أ]K
#
# Edit:    R_[؛]I_[ ]KR_[أ]K
# Pnx:     R_[؛]KKK
# NoPnx:   KI_[ ]KR_[أ]K
#
# Edit:    R_[.]I_[ ]DKR_[ن]
# Pnx:     R_[.]KKK
# NoPnx:   KI_[ ]DKR_[ن]
#
# Edit:    R_[!]I_[ ]KK
# Pnx:     R_[!]KK
# NoPnx:   KI_[ ]KK
#
# Edit:    R_[،]I_[ ]R_[ف]K
# Pnx:     R_[،]KK
# NoPnx:   KI_[ ]R_[ف]K
#
# Edit:    R_[ ]I_[.]DDD
# Pnx:     KI_[.]KKK
# NoPnx:   R_[ ]DDD
#
# Edit:    I_[م]KKR_[ ]I_[.]
# Pnx:     KKKI_[.]
# NoPnx:   I_[م]KKR_[ ]
#
# Edit:    MI_[-]KKK
# Pnx:     KI_[-]KKK
# NoPnx:   MKKK
#
# Edit:    R_[أ]KKKR_[ ]I_[.]D
# Pnx:     KKKKKI_[.]K
# NoPnx:   R_[أ]KKKR_[ ]D
#
# Edit:    R_[ ]I_[؟]
# Pnx:     KI_[؟]
# NoPnx:   R_[ ]
#
# Edit:    KR_[ي]KR_[ت]I_[ ]R_[.]
# Pnx:     KKKKR_[.]
# NoPnx:   KR_[ي]KR_[ت]I_[ ]K
#
# Edit:    KKR_[ ]I_[،]
# Pnx:     KKKI_[،]
# NoPnx:   KKR_[ ]
#
# Edit:    R_[؛]I_[ ]KR_[أ]KK
# Pnx:     R_[؛]KKKK
# NoPnx:   KI_[ ]KR_[أ]KK
#
# Edit:    KKKKI_[ي]KR_[ ]I_[،]
# Pnx:     KKKKKKI_[،]
# NoPnx:   KKKKI_[ي]KR_[ ]
#
# Edit:    I_[؟]R_[ ]I_[إ]K
# Pnx:     I_[؟]KK
# NoPnx:   R_[ ]I_[إ]K
#
# Edit:    I_[ ]R_[:]
# Pnx:     R_[:]
# NoPnx:   I_[ ]K
#
# Edit:    KKR_[ ]I_[:]
# Pnx:     KKKI_[:]
# NoPnx:   KKR_[ ]
#
# Edit:    MR_[,]
# Pnx:     KR_[,]
# NoPnx:   MK
#
# Edit:    KKKR_[ ]I_[،]
# Pnx:     KKKKI_[،]
# NoPnx:   KKKR_[ ]
#
# Edit:    KI_[,]KKK
# Pnx:     KI_[,]KKK
# NoPnx:   KKKK
#
# Edit:    R_[ه]I_[ ]R_[.]
# Pnx:     KR_[.]
# NoPnx:   R_[ه]I_[ ]K
#
# Edit:    R_[ ]I_[:]
# Pnx:     KI_[:]
# NoPnx:   R_[ ]
#
# Edit:    R_[:]I_[ ]R_[آ]
# Pnx:     R_[:]K
# NoPnx:   KI_[ ]R_[آ]
#
# Edit:    I_[ب]KR_[ ]I_[،]
# Pnx:     KKI_[،]
# NoPnx:   I_[ب]KR_[ ]
#
# Edit:    I_[%]
# Pnx:     I_[%]
# NoPnx:
#
# Edit:    R_[ ]I_[.]D
# Pnx:     KI_[.]K
# NoPnx:   R_[ ]D
#
# Edit:    R_[ ]I_[؟]DD
# Pnx:     KI_[؟]KK
# NoPnx:   R_[ ]DD
#
# Edit:    I_[ل]KKKI_[,]K
# Pnx:     KKKI_[,]K
# NoPnx:   I_[ل]KKKK
#
# Edit:    R_[%]
# Pnx:     R_[%]
# NoPnx:   K
#
# Edit:    R_[,]
# Pnx:     R_[,]
# NoPnx:   K
#
# Edit:    I_[2]KKI_[,]K
# Pnx:     KKI_[,]K
# NoPnx:   I_[2]KKK
#
# Edit:    I_[.]DDDD
# Pnx:     I_[.]KKKK
# NoPnx:   DDDD
#
# Edit:    I_[ ]R_[،]
# Pnx:     R_[،]
# NoPnx:   I_[ ]K
#
# Edit:    KKR_[ ]I_[.]
# Pnx:     KKKI_[.]
# NoPnx:   KKR_[ ]
#
# Edit:    KKI_[,]K
# Pnx:     KKI_[,]K
# NoPnx:   KKK
#
# Edit:    I_[أ]KKR_[ ]I_[،]
# Pnx:     KKKI_[،]
# NoPnx:   I_[أ]KKR_[ ]
#
# Edit:    R_[ ]I_[؟]D
# Pnx:     KI_[؟]K
# NoPnx:   R_[ ]D
#
# Edit:    MI_[.]KK
# Pnx:     KI_[.]KK
# NoPnx:   MKK
#
# Edit:    R_[?]
# Pnx:     R_[?]
# NoPnx:   K
#
# Edit:    KR_[ا]I_[ ]R_[،]
# Pnx:     KKR_[،]
# NoPnx:   KR_[ا]I_[ ]K
#
# Edit:    R_[ ]I_[،]DD
# Pnx:     KI_[،]KK
# NoPnx:   R_[ ]DD
#
# Edit:    R_[ ]I_[؛]
# Pnx:     KI_[؛]
# NoPnx:   R_[ ]
#
# Edit:    R_[.]I_[ ]DKKK
# Pnx:     R_[.]KKKK
# NoPnx:   KI_[ ]DKKK
#
# Edit:    R_[،]I_[ ]K
# Pnx:     R_[،]K
# NoPnx:   KI_[ ]K
#
# Edit:    KKKR_[م]I_[ ]R_[،]
# Pnx:     KKKKR_[،]
# NoPnx:   KKKR_[م]I_[ ]K
#
# Edit:    KKKR_[ ]I_[.]
# Pnx:     KKKKI_[.]
# NoPnx:   KKKR_[ ]
#
# Edit:    R_[{]
# Pnx:     R_[{]
# NoPnx:   K
#
# Edit:    R_[}]
# Pnx:     R_[}]
# NoPnx:   K
#
# Edit:    KKKKKKR_[ ]I_[،]
# Pnx:     KKKKKKKI_[،]
# NoPnx:   KKKKKKR_[ ]
#
# Edit:    R_[.]I_[ ]KK
# Pnx:     R_[.]KK
# NoPnx:   KI_[ ]KK
#
# Edit:    I_[/]
# Pnx:     I_[/]
# NoPnx:
#
# Edit:    I_[ا]KR_[ ]I_[.]
# Pnx:     KKI_[.]
# NoPnx:   I_[ا]KR_[ ]
#
# Edit:    KKKI_[,]K
# Pnx:     KKKI_[,]K
# NoPnx:   KKKK
#
# Edit:    R_[؟]I_[ ]R_[أ]
# Pnx:     R_[؟]K
# NoPnx:   KI_[ ]R_[أ]
#
# Edit:    I_[.]K
# Pnx:     I_[.]K
# NoPnx:   K
#
# Edit:    KKKKKKKKKR_[ ]I_[.]
# Pnx:     KKKKKKKKKKI_[.]
# NoPnx:   KKKKKKKKKR_[ ]
#
# Edit:    R_[،]I_[ ]KKK
# Pnx:     R_[،]KKK
# NoPnx:   KI_[ ]KKK
#
# Edit:    KKI_[,]KK
# Pnx:     KKI_[,]KK
# NoPnx:   KKKK
#
# Edit:    KI_[,]KK
# Pnx:     KI_[,]KK
# NoPnx:   KKK
#
# Edit:    R_[.]I_[ ]KR_[ظ]
# Pnx:     R_[.]KK
# NoPnx:   KI_[ ]KR_[ظ]
#
# Edit:    R_[.]I_[ ]DK
# Pnx:     R_[.]KK
# NoPnx:   KI_[ ]DK
#
# Edit:    R_[،]I_[ ]DK
# Pnx:     R_[،]KK
# NoPnx:   KI_[ ]DK
#
# Edit:    I_[.]DD
# Pnx:     I_[.]KK
# NoPnx:   DD
#
# Edit:    DDKKKKKR_[ ]I_[،]D
# Pnx:     KKKKKKKKI_[،]K
# NoPnx:   DDKKKKKR_[ ]D
#
# Edit:    I_[{]
# Pnx:     I_[{]
# NoPnx:
#
# Edit:    I_[}]
# Pnx:     I_[}]
# NoPnx:
#
# Edit:    KR_[أ]KR_[ ]I_[؛]
# Pnx:     KKKKI_[؛]
# NoPnx:   KR_[أ]KR_[ ]
#
# Edit:    I_[ا]KR_[ ]I_[،]D
# Pnx:     KKI_[،]K
# NoPnx:   I_[ا]KR_[ ]D
#
# Edit:    KKKKKKR_[ ]I_[.]D
# Pnx:     KKKKKKKI_[.]K
# NoPnx:   KKKKKKR_[ ]D
#
# Edit:    R_[-]DD
# Pnx:     R_[-]KK
# NoPnx:   KDD
#
# Edit:    KR_[ ]I_[،]D
# Pnx:     KKI_[،]K
# NoPnx:   KR_[ ]D
#
# Edit:    KKR_[ ]I_[-]
# Pnx:     KKKI_[-]
# NoPnx:   KKR_[ ]
#
# Edit:    R_[:]I_[ ]KR_[أ]
# Pnx:     R_[:]KK
# NoPnx:   KI_[ ]KR_[أ]
#
# Edit:    R_[أ]KKR_[ ]I_[،]
# Pnx:     KKKKI_[،]
# NoPnx:   R_[أ]KKR_[ ]
#
# Edit:    KKKR_[ ]I_[،]DDDDDDD
# Pnx:     KKKKI_[،]KKKKKKK
# NoPnx:   KKKR_[ ]DDDDDDD
#
# Edit:    I_[. ]KKKR_[ ]I_[.]DDD
# Pnx:     KKKKI_[.]KKK
# NoPnx:   I_[. ]KKKR_[ ]DDD
#
# Edit:    R_[،]I_[ ]D
# Pnx:     R_[،]K
# NoPnx:   KI_[ ]D
#
# Edit:    KR_[ ]I_[،]DD
# Pnx:     KKI_[،]KK
# NoPnx:   KR_[ ]DD
#
# Edit:    I_[ ]R_[،]I_[ إ]K
# Pnx:     R_[،]K
# NoPnx:   I_[ ]KI_[ إ]K
#
# Edit:    R_[.]I_[ ]K
# Pnx:     R_[.]K
# NoPnx:   KI_[ ]K
#
# Edit:    I_[، ]KKKR_[ ]I_[،]DDD
# Pnx:     KKKKI_[،]KKK
# NoPnx:   I_[، ]KKKR_[ ]DDD
#
# Edit:    KR_[ي]I_[ ]R_[،]
# Pnx:     KKR_[،]
# NoPnx:   KR_[ي]I_[ ]K
#
# Edit:    KKKKKR_[ ]I_[؛]
# Pnx:     KKKKKKI_[؛]
# NoPnx:   KKKKKR_[ ]
#
# Edit:    I_[,]
# Pnx:     I_[,]
# NoPnx:
#
# Edit:    KKKKR_[ ]I_[،]
# Pnx:     KKKKKI_[،]
# NoPnx:   KKKKR_[ ]
#
# Edit:    R_[ ]I_[.]R_[ ]I_[.]
# Pnx:     KI_[.]KI_[.]
# NoPnx:   R_[ ]R_[ ]
#
# Edit:    R_[ ]I_[.]R_[ ]
# Pnx:     KI_[.]K
# NoPnx:   R_[ ]R_[ ]
#
# Edit:    R_[،]I_[ ]DKK
# Pnx:     R_[،]KKK
# NoPnx:   KI_[ ]DKK
#
# Edit:    R_[،]I_[ ]R_[أ]KK
# Pnx:     R_[،]KKK
# NoPnx:   KI_[ ]R_[أ]KK
#
# Edit:    R_[ا]I_[ ]R_[-]DD
# Pnx:     KR_[-]KK
# NoPnx:   R_[ا]I_[ ]KDD
#
# Edit:    R_[ة]I_[ ]R_[.]
# Pnx:     KR_[.]
# NoPnx:   R_[ة]I_[ ]K
#
# Edit:    I_[.]D
# Pnx:     I_[.]K
# NoPnx:   D
#
# Edit:    R_[م]I_[ ]R_[،]
# Pnx:     KR_[،]
# NoPnx:   R_[م]I_[ ]K
#
# Edit:    R_[.]I_[ ]D
# Pnx:     R_[.]K
# NoPnx:   KI_[ ]D
#
# Edit:    R_[ث]KKR_[ ]I_[،]
# Pnx:     KKKKI_[،]
# NoPnx:   R_[ث]KKR_[ ]
#
# Edit:    I_[.]R_[ ]I_[إ]KK
# Pnx:     I_[.]KKK
# NoPnx:   R_[ ]I_[إ]KK
#
# Edit:    I_[ ]KR_[ه]I_[ ]R_["]
# Pnx:     KKR_["]
# NoPnx:   I_[ ]KR_[ه]I_[ ]K
#
# Edit:    R_[،]I_[ هذ]K
# Pnx:     R_[،]K
# NoPnx:   KI_[ هذ]K
#
# Edit:    R_[.]I_[ ]KKKK
# Pnx:     R_[.]KKKK
# NoPnx:   KI_[ ]KKKK
#
# Edit:    R_[.]D
# Pnx:     R_[.]K
# NoPnx:   KD
#
# Edit:    I_[ي]KKR_[ ]I_[،]
# Pnx:     KKKI_[،]
# NoPnx:   I_[ي]KKR_[ ]
#
# Edit:    KKKKR_[ ]I_[.]
# Pnx:     KKKKKI_[.]
# NoPnx:   KKKKR_[ ]
#
# Edit:    R_[،]I_[ ]KR_[و]K
# Pnx:     R_[،]KKK
# NoPnx:   KI_[ ]KR_[و]K
#
# Edit:    KKR_[ ]I_["]D
# Pnx:     KKKI_["]K
# NoPnx:   KKR_[ ]D
#
# Edit:    R_[ ]I_[،]R_[ ]I_[هذه]
# Pnx:     KI_[،]K
# NoPnx:   R_[ ]R_[ ]I_[هذه]
#
# Edit:    I_["]D
# Pnx:     I_["]K
# NoPnx:   D
#
# Edit:    MKI_[%]
# Pnx:     KKI_[%]
# NoPnx:   MK
#
# Edit:    R_[-]D
# Pnx:     R_[-]K
# NoPnx:   KD
#
# Edit:    R_[-]I_[ ]KK
# Pnx:     R_[-]KK
# NoPnx:   KI_[ ]KK
#
# Edit:    R_[إ]KKKKKKKR_[ ]I_[،]
# Pnx:     KKKKKKKKKI_[،]
# NoPnx:   R_[إ]KKKKKKKR_[ ]
#
# Edit:    I_[’]
# Pnx:     I_[’]
# NoPnx:
#
# Edit:    KKKKR_[ ]I_[:]
# Pnx:     KKKKKI_[:]
# NoPnx:   KKKKR_[ ]
#
# Edit:    I_[ ]R_[.]R_[ ]
# Pnx:     R_[.]K
# NoPnx:   I_[ ]KR_[ ]
#
# Edit:    R_[؟]I_[ ]KKI_[ ]K
# Pnx:     R_[؟]KKK
# NoPnx:   KI_[ ]KKI_[ ]K
#
# Edit:    R_[،]I_[ ]DKKK
# Pnx:     R_[،]KKKK
# NoPnx:   KI_[ ]DKKK
#
# Edit:    R_[:]I_[ ]KK
# Pnx:     R_[:]KK
# NoPnx:   KI_[ ]KK
#
# Edit:    R_[؟]I_[ ]KR_[أ]DK
# Pnx:     R_[؟]KKKK
# NoPnx:   KI_[ ]KR_[أ]DK
#
# Edit:    R_[ ]I_[؛]D
# Pnx:     KI_[؛]K
# NoPnx:   R_[ ]D
#
# Edit:    R_[،]D
# Pnx:     R_[،]K
# NoPnx:   KD
#
# Edit:    I_[,]KKK
# Pnx:     I_[,]KKK
# NoPnx:   KKK
#
# Edit:    KKKR_[ ]I_[؟]
# Pnx:     KKKKI_[؟]
# NoPnx:   KKKR_[ ]
#
# Edit:    R_[،]I_[ ]R_[إ]K
# Pnx:     R_[،]KK
# NoPnx:   KI_[ ]R_[إ]K
#
# Edit:    R_[ه]I_[ ]R_[:]
# Pnx:     KR_[:]
# NoPnx:   R_[ه]I_[ ]K
#
# Edit:    R_[،]I_[ ]DDDDD
# Pnx:     R_[،]KKKKK
# NoPnx:   KI_[ ]DDDDD
#
# Edit:    KKKKKKKKKKR_[ ]I_[،]
# Pnx:     KKKKKKKKKKKI_[،]
# NoPnx:   KKKKKKKKKKR_[ ]
#
# Edit:    R_[ء]I_[ ]R_[.]
# Pnx:     KR_[.]
# NoPnx:   R_[ء]I_[ ]K
#
# Edit:    KR_[م]I_[ ]R_[،]
# Pnx:     KKR_[،]
# NoPnx:   KR_[م]I_[ ]K
#
# Edit:    R_[م]I_[ ]R_[؟]
# Pnx:     KR_[؟]
# NoPnx:   R_[م]I_[ ]K
#
# Edit:    I_[ا]KI_[ن]KR_[ ]I_[.]
# Pnx:     KKKI_[.]
# NoPnx:   I_[ا]KI_[ن]KR_[ ]
#
# Edit:    R_[:]I_[ ]K
# Pnx:     R_[:]K
# NoPnx:   KI_[ ]K
#
# Edit:    KKI_[ي]KKR_[ ]I_[،]
# Pnx:     KKKKKI_[،]
# NoPnx:   KKI_[ي]KKR_[ ]
#
# Edit:    MI_[.]KR_[ي]
# Pnx:     KI_[.]KK
# NoPnx:   MKR_[ي]
#
# Edit:    R_[؟]I_[ ]R_[ل]R_[أ]K
# Pnx:     R_[؟]KKK
# NoPnx:   KI_[ ]R_[ل]R_[أ]K
#
# Edit:    R_[؟]I_[ ]K
# Pnx:     R_[؟]K
# NoPnx:   KI_[ ]K
#
# Edit:    R_[ز]I_[ ]R_[،]D
# Pnx:     KR_[،]K
# NoPnx:   R_[ز]I_[ ]KD
#
# Edit:    R_[،]I_[ ]DKKKKI_[ا]
# Pnx:     R_[،]KKKKK
# NoPnx:   KI_[ ]DKKKKI_[ا]
#
# Edit:    R_[،]I_[ ]R_[آ]
# Pnx:     R_[،]K
# NoPnx:   KI_[ ]R_[آ]
#
# Edit:    I_[ ]KKI_[,]K
# Pnx:     KKI_[,]K
# NoPnx:   I_[ ]KKK
#
# Edit:    I_[أ]KKR_[ ]I_[.]
# Pnx:     KKKI_[.]
# NoPnx:   I_[أ]KKR_[ ]
#
# Edit:    KI_[وتي]KR_[ ]I_["]D
# Pnx:     KKKI_["]K
# NoPnx:   KI_[وتي]KR_[ ]D
#
# Edit:    R_[ه]I_[ ]R_[،]
# Pnx:     KR_[،]
# NoPnx:   R_[ه]I_[ ]K
#
# Edit:    MKKKKI_[.]
# Pnx:     KKKKKI_[.]
# NoPnx:   MKKKK
#
# Edit:    MR_[أ]KI_[.]
# Pnx:     KKKI_[.]
# NoPnx:   MR_[أ]K
#
# Edit:    KR_[أ]I_[ ]R_[.]
# Pnx:     KKR_[.]
# NoPnx:   KR_[أ]I_[ ]K
#
# Edit:    R_[م]I_[ ]R_[.]
# Pnx:     KR_[.]
# NoPnx:   R_[م]I_[ ]K
#
# Edit:    R_[ ]I_[،]R_[ ]I_[إ]K
# Pnx:     KI_[،]KK
# NoPnx:   R_[ ]R_[ ]I_[إ]K
#
# Edit:    KI_[ذ]KR_[ ]I_[.]
# Pnx:     KKKI_[.]
# NoPnx:   KI_[ذ]KR_[ ]
#
# Edit:    R_[.]I_[ أ]KK
# Pnx:     R_[.]KK
# NoPnx:   KI_[ أ]KK
#
# Edit:    R_[.]I_[ ]R_[.]
# Pnx:     R_[.]R_[.]
# NoPnx:   KI_[ ]K
#
# Edit:    R_[م]I_[ ]R_[!]
# Pnx:     KR_[!]
# NoPnx:   R_[م]I_[ ]K
#
# Edit:    MR_[٪]
# Pnx:     KR_[٪]
# NoPnx:   MK
#
# Edit:    KKKKKR_[ ]I_[،]
# Pnx:     KKKKKKI_[،]
# NoPnx:   KKKKKR_[ ]
#
# Edit:    R_[،]I_[ ]KR_[أ]KK
# Pnx:     R_[،]KKKK
# NoPnx:   KI_[ ]KR_[أ]KK
#
# Edit:    KKI_[%]
# Pnx:     KKI_[%]
# NoPnx:   KK
#
# Edit:    MKKI_[%]
# Pnx:     KKKI_[%]
# NoPnx:   MKK
#
# Edit:    R_[؟]I_[ ]D
# Pnx:     R_[؟]K
# NoPnx:   KI_[ ]D
#
# Edit:    R_[ ]I_[؟]R_[ ]
# Pnx:     KI_[؟]K
# NoPnx:   R_[ ]R_[ ]
#
# Edit:    MI_[.]K
# Pnx:     KI_[.]K
# NoPnx:   MK
#
# Edit:    MKKR_[آ]KI_[.]
# Pnx:     KKKKKI_[.]
# NoPnx:   MKKR_[آ]K
#
# Edit:    MR_[آ]KI_[.]
# Pnx:     KKKI_[.]
# NoPnx:   MR_[آ]K
#
# Edit:    R_[؛]I_[ ]KR_[أ]KKK
# Pnx:     R_[؛]KKKKK
# NoPnx:   KI_[ ]KR_[أ]KKK
#
# Edit:    R_[:]I_[ ]R_[أ]KD
# Pnx:     R_[:]KKK
# NoPnx:   KI_[ ]R_[أ]KD
#
# Edit:    I_[ج]R_[ر]R_[ ]R_[.]
# Pnx:     KKR_[.]
# NoPnx:   I_[ج]R_[ر]R_[ ]K
#
# Edit:    KKI_[.]
# Pnx:     KKI_[.]
# NoPnx:   KK
#
# Edit:    KI_[.]
# Pnx:     KI_[.]
# NoPnx:   K
#
# Edit:    R_[٪]
# Pnx:     R_[٪]
# NoPnx:   K
#
# Edit:    DKI_[ا]KR_[ ]I_[،]
# Pnx:     KKKKI_[،]
# NoPnx:   DKI_[ا]KR_[ ]
#
# Edit:    KKKKKKKR_[ ]I_[؟]
# Pnx:     KKKKKKKKI_[؟]
# NoPnx:   KKKKKKKR_[ ]
#
# Edit:    MR_[،]
# Pnx:     KR_[،]
# NoPnx:   MK
#
# Edit:    R_[؟]I_[ ]KR_[ك]I_[ن]
# Pnx:     R_[؟]KK
# NoPnx:   KI_[ ]KR_[ك]I_[ن]
#
# Edit:    MR_[؟]
# Pnx:     KR_[؟]
# NoPnx:   MK
#
# Edit:    R_[.]DDDDDDD
# Pnx:     R_[.]KKKKKKK
# NoPnx:   KDDDDDDD
#
# Edit:    KKR_[ ]I_[؟]
# Pnx:     KKKI_[؟]
# NoPnx:   KKR_[ ]
#
# Edit:    MR_[.]
# Pnx:     KR_[.]
# NoPnx:   MK
#
# Edit:    I_[ ]R_[،]I_[ ]K
# Pnx:     R_[،]K
# NoPnx:   I_[ ]KI_[ ]K
#
# Edit:    R_[ ]I_[)]D
# Pnx:     KI_[)]K
# NoPnx:   R_[ ]D
#
# Edit:    R_[،]I_[ ]R_[أ]DKK
# Pnx:     R_[،]KKKK
# NoPnx:   KI_[ ]R_[أ]DKK
#
# Edit:    R_[.]I_[ ]R_[أ]KR_[ج]R_[و]
# Pnx:     R_[.]KKKK
# NoPnx:   KI_[ ]R_[أ]KR_[ج]R_[و]
#
# Edit:    R_[؛]I_[ ]KR_[أ]
# Pnx:     R_[؛]KK
# NoPnx:   KI_[ ]KR_[أ]
#
# Edit:    KR_[ئ]I_[ ]R_[.]
# Pnx:     KKR_[.]
# NoPnx:   KR_[ئ]I_[ ]K
#
# Edit:    R_[،]I_[ ]KKKK
# Pnx:     R_[،]KKKK
# NoPnx:   KI_[ ]KKKK
#
# Edit:    R_[،]I_[ ]R_[ص]R_[م]K
# Pnx:     R_[،]KKK
# NoPnx:   KI_[ ]R_[ص]R_[م]K
#
# Edit:    R_[.]I_[ ]KKI_[ أ]K
# Pnx:     R_[.]KKK
# NoPnx:   KI_[ ]KKI_[ أ]K
#
# Edit:    I_[ا]KR_[ ]I_[؟]D
# Pnx:     KKI_[؟]K
# NoPnx:   I_[ا]KR_[ ]D
#
# Edit:    R_[،]I_[ ]DKDK
# Pnx:     R_[،]KKKK
# NoPnx:   KI_[ ]DKDK
#
# Edit:    KKR_[ ]I_[؟]D
# Pnx:     KKKI_[؟]K
# NoPnx:   KKR_[ ]D
#
# Edit:    KKR_[ ]I_[!]
# Pnx:     KKKI_[!]
# NoPnx:   KKR_[ ]
#
# Edit:    R_[،]DDDDD
# Pnx:     R_[،]KKKKK
# NoPnx:   KDDDDD
#
# Edit:    KI_[؟]
# Pnx:     KI_[؟]
# NoPnx:   K
#
# Edit:    R_[.]I_[ ]KKR_[إ]K
# Pnx:     R_[.]KKKK
# NoPnx:   KI_[ ]KKR_[إ]K
#
# Edit:    R_[‘]KKKK
# Pnx:     R_[‘]KKKK
# NoPnx:   KKKKK
#
# Edit:    I_[*]
# Pnx:     I_[*]
# NoPnx:
#
# Edit:    MI_["]KKK
# Pnx:     KI_["]KKK
# NoPnx:   MKKK
#
# Edit:    KKKI_["]
# Pnx:     KKKI_["]
# NoPnx:   KKK
#
# Edit:    I_[ام]KR_[ ]I_[،]DD
# Pnx:     KKI_[،]KK
# NoPnx:   I_[ام]KR_[ ]DD
#
# Edit:    R_[،]I_[ ]KR_[أ]R_[ج]R_[ل]
# Pnx:     R_[،]KKKK
# NoPnx:   KI_[ ]KR_[أ]R_[ج]R_[ل]
#
# Edit:    R_[.]DD
# Pnx:     R_[.]KK
# NoPnx:   KDD
#
# Edit:    R_[،]I_[ ]R_[ل]I_[كن]
# Pnx:     R_[،]K
# NoPnx:   KI_[ ]R_[ل]I_[كن]
#
# Edit:    I_[،]DD
# Pnx:     I_[،]KK
# NoPnx:   DD
#
# Edit:    R_[+]
# Pnx:     R_[+]
# NoPnx:   K
#
# Edit:    R_[،]I_[ ]R_[أ]R_[ن]
# Pnx:     R_[،]KK
# NoPnx:   KI_[ ]R_[أ]R_[ن]
#
# Edit:    R_[ة]I_[ ]R_[،]D
# Pnx:     KR_[،]K
# NoPnx:   R_[ة]I_[ ]KD
#
# Edit:    R_[ت]I_[ ]R_[،]D
# Pnx:     KR_[،]K
# NoPnx:   R_[ت]I_[ ]KD
#
# Edit:    I_[،]DDD
# Pnx:     I_[،]KKK
# NoPnx:   DDD
#
# Edit:    R_[آ]KKR_[ ]I_[،]
# Pnx:     KKKKI_[،]
# NoPnx:   R_[آ]KKR_[ ]
#
# Edit:    I_[،]R_[ ]
# Pnx:     I_[،]K
# NoPnx:   R_[ ]
#
# Edit:    MR_[-]
# Pnx:     KR_[-]
# NoPnx:   MK
#
# Edit:    R_[ ]I_[،]R_[ ]
# Pnx:     KI_[،]K
# NoPnx:   R_[ ]R_[ ]
#
# Edit:    KR_[ ]I_[.]DD
# Pnx:     KKI_[.]KK
# NoPnx:   KR_[ ]DD
#
# Edit:    KR_[ه]I_[ ]R_[،]
# Pnx:     KKR_[،]
# NoPnx:   KR_[ه]I_[ ]K
#
# Edit:    R_[ى]I_[ ]R_[،]
# Pnx:     KR_[،]
# NoPnx:   R_[ى]I_[ ]K
#
# Edit:    R_[؛]I_[ ]KR_[أ]DK
# Pnx:     R_[؛]KKKK
# NoPnx:   KI_[ ]KR_[أ]DK
#
# Edit:    KR_[ا]I_[ ]R_[!]D
# Pnx:     KKR_[!]K
# NoPnx:   KR_[ا]I_[ ]KD
#
# Edit:    R_[.]I_[ ]R_[غ]R_[د]K
# Pnx:     R_[.]KKK
# NoPnx:   KI_[ ]R_[غ]R_[د]K
#
# Edit:    I_[،]R_[ ]I_[أ]KK
# Pnx:     I_[،]KKK
# NoPnx:   R_[ ]I_[أ]KK
#
# Edit:    I_[؟]R_[ ]I_[أ]KK
# Pnx:     I_[؟]KKK
# NoPnx:   R_[ ]I_[أ]KK
#
# Edit:    I_[ ]R_[،]DDD
# Pnx:     R_[،]KKK
# NoPnx:   I_[ ]KDDD
#
# Edit:    R_[ ]I_[،]DDDDDDD
# Pnx:     KI_[،]KKKKKKK
# NoPnx:   R_[ ]DDDDDDD
